# %%
import matplotlib.pyplot as plt
import numpy as np
import string
import cv2




# 3x3 Identity transformation matrix
I = np.eye(3)

# create the scaling transformation matrix
T_s = np.array([[2, 0, 0], [0, 2, 0], [0, 0, 1]])

# create the rotation transformation matrix
T_r = np.array([[0, 1, 0], [-1, 0, 0], [0, 0, 1]])

# create the rotation transformation matrix
T_k = np.array([[1, 0, 0], [-0, -1, 0], [0, 0, 1]])

#MAtrix espejo
T_m= np.array([[-1, 0, 0], [0, -1, 0], [0, 0, 1]])

T_sk= np.array([[1, 1, 0], [0, 1, 0], [0, 0, 1]])

T_sks= np.array([[0, 1, 0], [1, 1, 0], [0, 0, 1]])
# create combined tranformation matrix
T = T_s @ T_r


#angle 45
Tangle=np.array([[0, 1.5, 0], [-1, 0, 0], [0, 0, 1]])

# %%
# Escala
img = plt.imread('lena.jpeg')
#img=plt.imread('letterR.jpg')
#img=plt.imread('dice.png')
#img.shape#(600, 900, 3)

img_transformed = np.empty((510, 510, 3), dtype=np.uint8)
for i, row in enumerate(img):
    for j, col in enumerate(row):
        pixel_data = img[i, j,:]
        input_coords = np.array([i, j,1])
        i_out, j_out, _ = T_s @ input_coords
        img_transformed[i_out, j_out] = pixel_data

plt.figure(figsize=(5, 5))
plt.imshow(img_transformed)
cv2.imwrite('lenaEscale.jpg', img_transformed)
# Out:
# True

# %%
# Escala
img2 = plt.imread('lena.jpeg')
#img=plt.imread('letterR.jpg')
#img=plt.imread('dice.png')
#img.shape#(600, 900, 3)

img_transformed2 = np.empty((255, 255, 3), dtype=np.uint8)
for i, row in enumerate(img2):
    for j, col in enumerate(row):
        pixel_data = img2[i, j,:]
        input_coords = np.array([i, j,1])
        i_out, j_out, _ = T_r @ input_coords
        img_transformed2[i_out, j_out] = pixel_data

plt.figure(figsize=(5, 5))
plt.imshow(img_transformed2)
cv2.imwrite('llenaRotae.jpg', img_transformed2)
# Out:
# True

# %%
# Escala
img3 = plt.imread('lena.jpeg')
#img=plt.imread('letterR.jpg')
#img=plt.imread('dice.png')
#img.shape#(600, 900, 3)

img_transformed3 = np.empty((255, 255, 3), dtype=np.uint8)
for i, row in enumerate(img3):
    for j, col in enumerate(row):
        pixel_data = img3[i, j,:]
        input_coords = np.array([i, j,1])
        i_out, j_out, _ = T_k @ input_coords
        img_transformed3[i_out, j_out] = pixel_data

plt.figure(figsize=(5, 5))
plt.imshow(img_transformed3)
cv2.imwrite('mirrorh.jpg', img_transformed3)
# Out:
# True

# %%
# Escala
img4 = plt.imread('lena.jpeg')
#img=plt.imread('letterR.jpg')
#img=plt.imread('dice.png')
#img.shape#(600, 900, 3)

img_transformed4 = np.empty((255, 255, 3), dtype=np.uint8)
for i, row in enumerate(img4):
    for j, col in enumerate(row):
        pixel_data = img4[i, j,:]
        input_coords = np.array([i, j,1])
        i_out, j_out, _ = T_m @ input_coords
        img_transformed4[i_out, j_out] = pixel_data

plt.figure(figsize=(5, 5))
plt.imshow(img_transformed4)
cv2.imwrite('rotateagain.jpg', img_transformed4)
# Out:
# True

# %%
# Perspectiva
img5 = plt.imread('lena.jpeg')
#img=plt.imread('letterR.jpg')
#img=plt.imread('dice.png')
#img.shape#(600, 900, 3)

img_transformed5 = np.empty((510, 510, 3), dtype=np.uint8)
for i, row in enumerate(img5):
    for j, col in enumerate(row):
        pixel_data = img5[i, j,:]
        input_coords = np.array([i, j,1])
        i_out, j_out, _ =T_sk@ input_coords
        img_transformed5[i_out, j_out] = pixel_data

plt.figure(figsize=(5, 5))
plt.imshow(img_transformed5)
cv2.imwrite('perspective.jpg', img_transformed5)
# Out:
# True

# %%
# Perspectiva
img6 = plt.imread('lena.jpeg')
#img=plt.imread('letterR.jpg')
#img=plt.imread('dice.png')
#img.shape#(600, 900, 3)

img_transformed6 = np.empty((510, 510, 3), dtype=np.uint8)
for i, row in enumerate(img6):
    for j, col in enumerate(row):
        pixel_data = img6[i, j,:]
        input_coords = np.array([i, j,1])
        i_out, j_out, _ =T_sks@ input_coords
        img_transformed6[i_out, j_out] = pixel_data

plt.figure(figsize=(5, 5))
plt.imshow(img_transformed6)
cv2.imwrite('perspective2.jpg', img_transformed6)
# Out:
# True
